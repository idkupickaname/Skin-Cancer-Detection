# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from google.colab import drive
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import PIL

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Mount Google Drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Define file paths for training, testing, and validation CSV files
test_path = '/content/drive/MyDrive/DL/test_data.csv'
train_path = '/content/drive/MyDrive/DL/train_data.csv'
valid_path = '/content/drive/MyDrive/DL/valid_data.csv'

# %%
# Load CSV files into DataFrames
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
valid_df = pd.read_csv(valid_path)

# %%
# Display tail of the training DataFrame
train_df.tail()

# Define fractions for train-test split
fractions = np.array([0.8, 0.1, 0.1])

# Shuffle the training data
train_df = train_df.sample(frac=1)

# Split the data into train, validation, and test sets
train_set, temp_set = train_test_split(train_df, test_size=fractions[1], random_state=42)
valid_set, test_set = train_test_split(temp_set, test_size=fractions[2], random_state=42)

# %%
# Display lengths of the datasets
print("Training set length:", len(train_set))
print("Validation set length:", len(valid_set))
print("Test set length:", len(test_set))

# Display unique labels in the dataset
train_df.label.unique()
# Out:
# Training set length: 7210
# Validation set length: 721
# Test set length: 81
# array([6, 4, 1, 2, 0, 3, 5])

# %%
# Define classes
classes = {
    0: ('akiec', 'actinic keratoses and intraepithelial carcinomae'),
    1: ('bcc', 'basal cell carcinoma'),
    2: ('bkl', 'benign keratosis-like lesions'),
    3: ('df', 'dermatofibroma'),
    4: ('nv', 'melanocytic nevi'),
    5: ('vasc', 'pyogenic granulomas and hemorrhage'),
    6: ('mel', 'melanoma'),
}

# %%
# Extract features and labels for training set
y_train = train_set['label']
x_train = train_set.drop(columns=['label'])

# Extract features and labels for validation set
y_valid = valid_set['label']
x_valid = valid_set.drop(columns=['label'])

# Extract features and labels for test set
y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

# Convert x_train, x_valid, and x_test to NumPy arrays
x_train = np.array(x_train, dtype=np.uint8).reshape(-1, 28, 28, 3)
x_valid = np.array(x_valid, dtype=np.uint8).reshape(-1, 28, 28, 3)
x_test = np.array(x_test, dtype=np.uint8).reshape(-1, 28, 28, 3)

# Reshape x_train to 2D array
x_train_reshaped = x_train.reshape(x_train.shape[0], -1)

# %%
# Resample the training set using RandomOverSampler to address class imbalance
oversample = RandomOverSampler()
x_train_resampled, y_train_resampled = oversample.fit_resample(x_train_reshaped, y_train)

# Reshape x_train_resampled back to 4D array
x_train_resampled = x_train_resampled.reshape(x_train_resampled.shape[0], 28, 28, 3)

# %%
# Create a convolutional neural network model
model = Sequential()
model.add(Conv2D(16, kernel_size=(3, 3), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(Flatten())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(Dense(7, activation='softmax'))

# Display the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 28, 28, 16)        448
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 14, 14, 16)        64
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 32)        4640
#
#  conv2d_12 (Conv2D)          (None, 10, 10, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  batch_normalization_13 (Ba  (None, 5, 5, 64)          256
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 128)         73856
#
#  conv2d_14 (Conv2D)          (None, 1, 1, 256)         295168
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 256)               65792
#
#  batch_normalization_14 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_15 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  batch_normalization_16 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  batch_normalization_17 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dense_14 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 504103 (1.92 MB)
# Trainable params: 502983 (1.92 MB)
# Non-trainable params: 1120 (4.38 KB)
# _________________________________________________________________

# %%
# Define model callbacks
callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5',
                                              monitor='val_accuracy', mode='max',
                                              verbose=1, save_best_only=True)

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(lr=0.001)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
# Train the model
history = model.fit(x_train_resampled, y_train_resampled,
                    validation_data=(x_valid, y_valid),
                    batch_size=128,
                    epochs=50,
                    shuffle=True,
                    callbacks=[callback])
# Out:
# Epoch 1/50
# 265/265 [==============================] - ETA: 0s - loss: 1.2117 - accuracy: 0.5518
# Epoch 1: val_accuracy improved from -inf to 0.46047, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 8s 13ms/step - loss: 1.2117 - accuracy: 0.5518 - val_loss: 1.3887 - val_accuracy: 0.4605
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 262/265 [============================>.] - ETA: 0s - loss: 0.4205 - accuracy: 0.8520
# Epoch 2: val_accuracy improved from 0.46047 to 0.61165, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 4s 14ms/step - loss: 0.4194 - accuracy: 0.8523 - val_loss: 1.0563 - val_accuracy: 0.6117
# Epoch 3/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.2471 - accuracy: 0.9099
# Epoch 3: val_accuracy improved from 0.61165 to 0.65187, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 3s 13ms/step - loss: 0.2476 - accuracy: 0.9098 - val_loss: 1.3491 - val_accuracy: 0.6519
# Epoch 4/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.9392
# Epoch 4: val_accuracy improved from 0.65187 to 0.66713, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 3s 11ms/step - loss: 0.1719 - accuracy: 0.9393 - val_loss: 1.1995 - val_accuracy: 0.6671
# Epoch 5/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9557
# Epoch 5: val_accuracy improved from 0.66713 to 0.70319, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 3s 11ms/step - loss: 0.1258 - accuracy: 0.9557 - val_loss: 1.2622 - val_accuracy: 0.7032
# Epoch 6/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9658
# Epoch 6: val_accuracy did not improve from 0.70319
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0988 - accuracy: 0.9659 - val_loss: 1.3020 - val_accuracy: 0.6782
# Epoch 7/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0863 - accuracy: 0.9715
# Epoch 7: val_accuracy did not improve from 0.70319
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0864 - accuracy: 0.9714 - val_loss: 1.4271 - val_accuracy: 0.6477
# Epoch 8/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0744 - accuracy: 0.9753
# Epoch 8: val_accuracy improved from 0.70319 to 0.73925, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 4s 17ms/step - loss: 0.0744 - accuracy: 0.9752 - val_loss: 1.2492 - val_accuracy: 0.7393
# Epoch 9/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9784
# Epoch 9: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0654 - accuracy: 0.9783 - val_loss: 1.3582 - val_accuracy: 0.7018
# Epoch 10/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9852
# Epoch 10: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0454 - accuracy: 0.9852 - val_loss: 1.4204 - val_accuracy: 0.7143
# Epoch 11/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9819
# Epoch 11: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0540 - accuracy: 0.9817 - val_loss: 1.7247 - val_accuracy: 0.6602
# Epoch 12/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9866
# Epoch 12: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 13ms/step - loss: 0.0408 - accuracy: 0.9866 - val_loss: 1.6504 - val_accuracy: 0.6713
# Epoch 13/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9900
# Epoch 13: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 1.4751 - val_accuracy: 0.7393
# Epoch 14/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9886
# Epoch 14: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 1.4900 - val_accuracy: 0.7282
# Epoch 15/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9879
# Epoch 15: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0382 - accuracy: 0.9879 - val_loss: 1.8006 - val_accuracy: 0.7143
# Epoch 16/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9911
# Epoch 16: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0273 - accuracy: 0.9912 - val_loss: 1.6140 - val_accuracy: 0.7282
# Epoch 17/50
# 265/265 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9882
# Epoch 17: val_accuracy did not improve from 0.73925
# 265/265 [==============================] - 3s 12ms/step - loss: 0.0348 - accuracy: 0.9882 - val_loss: 1.4495 - val_accuracy: 0.7295
# Epoch 18/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9936
# Epoch 18: val_accuracy improved from 0.73925 to 0.74341, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 4s 17ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 1.5418 - val_accuracy: 0.7434
# Epoch 19/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9923
# Epoch 19: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 1.6306 - val_accuracy: 0.7157
# Epoch 20/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9904
# Epoch 20: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 1.8142 - val_accuracy: 0.6602
# Epoch 21/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9939
# Epoch 21: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 1.7893 - val_accuracy: 0.7074
# Epoch 22/50
# 265/265 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9926
# Epoch 22: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 11ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 1.5657 - val_accuracy: 0.7101
# Epoch 23/50
# 265/265 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9944
# Epoch 23: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 1.7047 - val_accuracy: 0.7226
# Epoch 24/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9919
# Epoch 24: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 12ms/step - loss: 0.0276 - accuracy: 0.9918 - val_loss: 1.5752 - val_accuracy: 0.7157
# Epoch 25/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9947
# Epoch 25: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 1.8400 - val_accuracy: 0.7004
# Epoch 26/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9943
# Epoch 26: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 1.6737 - val_accuracy: 0.7087
# Epoch 27/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9945
# Epoch 27: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 1.9954 - val_accuracy: 0.6852
# Epoch 28/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9925
# Epoch 28: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 3s 13ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 1.7963 - val_accuracy: 0.6838
# Epoch 29/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9953
# Epoch 29: val_accuracy did not improve from 0.74341
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 1.8349 - val_accuracy: 0.7032
# Epoch 30/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9928
# Epoch 30: val_accuracy improved from 0.74341 to 0.74619, saving model to /content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5
# 265/265 [==============================] - 3s 13ms/step - loss: 0.0224 - accuracy: 0.9929 - val_loss: 1.6989 - val_accuracy: 0.7462
# Epoch 31/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9975
# Epoch 31: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 1.7755 - val_accuracy: 0.7115
# Epoch 32/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9922
# Epoch 32: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0251 - accuracy: 0.9922 - val_loss: 1.8781 - val_accuracy: 0.7115
# Epoch 33/50
# 265/265 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9954
# Epoch 33: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 13ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 1.8641 - val_accuracy: 0.6810
# Epoch 34/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9961
# Epoch 34: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0128 - accuracy: 0.9961 - val_loss: 1.7058 - val_accuracy: 0.7309
# Epoch 35/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9954
# Epoch 35: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 11ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 1.7421 - val_accuracy: 0.7004
# Epoch 36/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9938
# Epoch 36: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0209 - accuracy: 0.9938 - val_loss: 1.6973 - val_accuracy: 0.7074
# Epoch 37/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9962
# Epoch 37: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 1.6901 - val_accuracy: 0.7171
# Epoch 38/50
# 265/265 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 38: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 11ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.8725 - val_accuracy: 0.7379
# Epoch 39/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9970
# Epoch 39: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0119 - accuracy: 0.9969 - val_loss: 1.8740 - val_accuracy: 0.6990
# Epoch 40/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9937
# Epoch 40: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 12ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 1.7351 - val_accuracy: 0.7295
# Epoch 41/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9962
# Epoch 41: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 1.9420 - val_accuracy: 0.6879
# Epoch 42/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9959
# Epoch 42: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 1.6091 - val_accuracy: 0.7379
# Epoch 43/50
# 264/265 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9959
# Epoch 43: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 1.7820 - val_accuracy: 0.7129
# Epoch 44/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9960
# Epoch 44: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 4s 13ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.7418 - val_accuracy: 0.7254
# Epoch 45/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9972
# Epoch 45: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 1.9188 - val_accuracy: 0.7032
# Epoch 46/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9969
# Epoch 46: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 1.9084 - val_accuracy: 0.7240
# Epoch 47/50
# 260/265 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9966
# Epoch 47: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 1.7028 - val_accuracy: 0.7462
# Epoch 48/50
# 261/265 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9961
# Epoch 48: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 10ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 1.9167 - val_accuracy: 0.7074
# Epoch 49/50
# 262/265 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9964
# Epoch 49: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 3s 11ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 1.6667 - val_accuracy: 0.7406
# Epoch 50/50
# 263/265 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9967
# Epoch 50: val_accuracy did not improve from 0.74619
# 265/265 [==============================] - 4s 14ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 1.7311 - val_accuracy: 0.7032

# %%
# Plot training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Load the best model weights
model.load_weights('/content/drive/MyDrive/Colab Notebooks/Skin Cancer/best_model.h5')

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 3/3 - 0s - loss: 1.2996 - accuracy: 0.7901 - 41ms/epoch - 14ms/step
# Test Loss: 1.2996
# Test Accuracy: 0.7901

# %%
# Make predictions on a sample image
image = PIL.Image.open('/content/drive/MyDrive/Skin-Cancer-Classification/1234214.jpg')
image = image.resize((28, 28))
img = np.array(image).reshape(-1, 28, 28, 3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-2aad4a0b37db> in <cell line: 2>()
#       1 # Make predictions on a sample image
# ----> 2 image = PIL.Image.open('/content/drive/MyDrive/Skin-Cancer-Classification/1234214.jpg')
#       3 image = image.resize((28, 28))
#       4 img = np.array(image).reshape(-1, 28, 28, 3)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Skin-Cancer-Classification/1234214.jpg'

# %%
# Make predictions
result = model.predict(img)
print(result[0])

# Convert predictions to a class index
result = result.argmax(axis=-1)[0]

# Print the predicted class
print(classes[result])

# %%
# Generate confusion matrix and classification report
y_pred = np.argmax(model.predict(x_test), axis=1)
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Confusion Matrix:
# [[ 0  2  1  1  0  0]
#  [ 0  3  0  0  0  0]
#  [ 1  0  1  6  0  0]
#  [ 0  0  1 52  0  2]
#  [ 0  0  0  0  2  0]
#  [ 0  0  0  3  0  6]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.60      1.00      0.75         3
#            2       0.33      0.12      0.18         8
#            4       0.84      0.95      0.89        55
#            5       1.00      1.00      1.00         2
#            6       0.75      0.67      0.71         9
#
#     accuracy                           0.79        81
#    macro avg       0.59      0.62      0.59        81
# weighted avg       0.73      0.79      0.75        81
