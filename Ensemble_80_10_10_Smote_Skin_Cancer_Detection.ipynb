# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
path='/content/drive/MyDrive/Skin-Cancer-Classification/hmnist_28_28_RGB.csv'

# %%
df=pd.read_csv(path)

# %%
df.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 10010        184        166        182        188  ...        208        185
# 10011        121        104        103        132  ...         96         79
# 10012        175        156        160        184  ...        204        181
# 10013        167        127        146        169  ...        185        162
# 10014        181        150        133        178  ...        159         79
#
#        pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 10010        187        208        186        186        206        187
# 10011         76         24         23         21          3          4
# 10012        178        181        159        153        172        151
# 10013        167        184        157        166        185        162
# 10014         82        174        137        125        175        139
#
#        pixel2351  label
# 10010        189      0
# 10011          1      0
# 10012        145      0
# 10013        172      0
# 10014        126      6
#
# [5 rows x 2353 columns]

# %%
fractions=np.array([0.6,0.4])
df=df.sample(frac=1)
train_set, test_set = np.array_split(
    df, (fractions[:-1].cumsum() * len(df)).astype(int))

# %%
print(len(train_set))
# Out:
# 6009

# %%
print(len(test_set))
# Out:
# 4006

# %%
df.label.unique()
# Out:
# array([2, 4, 6, 1, 0, 3, 5])

# %%
classes={0:('akiec', 'actinic keratoses and intraepithelial carcinomae'),
         1:('bcc' , 'basal cell carcinoma'),
         2:('bkl', 'benign keratosis-like lesions'),
         3:('df', 'dermatofibroma'),
         4:('nv', ' melanocytic nevi'),
         5:('vasc', ' pyogenic granulomas and hemorrhage'),
         6:('mel', 'melanoma'),}

# %%
y_train=train_set['label']
x_train=train_set.drop(columns=['label'])
y_test=test_set['label']
x_test=test_set.drop(columns=['label'])

columns=list(x_train)

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Map numeric labels to class names
class_names = [classes[i][0] for i in range(len(classes))]
y_train_names = y_train.map({i: class_names[i] for i in range(len(class_names))})

# Set the style for better visibility
sns.set(style="darkgrid")

# Create the count plot with annotations
ax = sns.countplot(y=y_train_names)

# Add annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.show()  # Display the plot

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler()
x_train,y_train  = oversample.fit_resample(x_train,y_train)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Map numeric labels to class names
class_names = [classes[i][0] for i in range(len(classes))]
y_train_names = y_train.map({i: class_names[i] for i in range(len(class_names))})

# Set the style for better visibility
sns.set(style="darkgrid")

# Create the count plot with annotations
ax = sns.countplot(y=y_train_names)

# Add annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import random
num=random.randint(0,8000)
x_train=np.array(x_train, dtype=np.uint8).reshape(-1,28,28,3)

plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()
num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
import tensorflow as tf

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Average, Flatten, Dropout, Dense, BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.applications import ResNet50

# ResNet50-based model
input_resnet50 = Input(shape=(32, 32, 3))
base_model_resnet50 = ResNet50(weights='imagenet', include_top=False, input_tensor=input_resnet50)
for layer in base_model_resnet50.layers:
    layer.trainable = False
output_resnet50 = Sequential([
    base_model_resnet50,
    Flatten(),
    Dropout(0.2),
    Dense(256, activation='relu'),   # Adjust the size if needed
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(7, activation='softmax')
])(input_resnet50)
model_resnet50 = Model(inputs=input_resnet50, outputs=output_resnet50)

# Custom CNN model
model_custom_cnn = Sequential([
    Conv2D(16, kernel_size=(3, 3), input_shape=(32, 32, 3), activation='relu', padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    Conv2D(256, kernel_size=(3, 3), activation='relu'),
    Flatten(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(7, activation='softmax')
])

# Combine the models using majority voting
input_combined = Input(shape=(32, 32, 3))
output_resnet50 = model_resnet50(input_combined)
output_custom_cnn = model_custom_cnn(input_combined)
ensemble_output = Average()([output_resnet50, output_custom_cnn])

# Build the ensemble model
ensemble_model = Model(inputs=input_combined, outputs=ensemble_output)

# Display the ensemble model summary
ensemble_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  model_3 (Functional)        (None, 7)                    2415763   ['input_9[0][0]']
#                                                           9
#
#  sequential_7 (Sequential)   (None, 7)                    700711    ['input_9[0][0]']
#
#  average (Average)           (None, 7)                    0         ['model_3[0][0]',
#                                                                      'sequential_7[0][0]']
#
# ==================================================================================================
# Total params: 24858350 (94.83 MB)
# Trainable params: 1268558 (4.84 MB)
# Non-trainable params: 23589792 (89.99 MB)
# __________________________________________________________________________________________________

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Res.h5',

    mode='max',
    verbose=1,
    save_best_only=True
)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Use learning_rate instead of lr
ensemble_model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Resize images to (32, 32)
x_train_resized = tf.image.resize(x_train, (32, 32))

# Fit the model
history = ensemble_model.fit(x_train_resized,
                    y_train,
                    validation_split=0.2,
                    batch_size=128,
                    epochs=50,
                    shuffle=True,
                    callbacks=[callback])
# Out:
# Epoch 1/50
# 178/178 [==============================] - ETA: 0s - loss: 1.0612 - accuracy: 0.6396
# Epoch 1: val_loss improved from -inf to 2.33162, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Res.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 178/178 [==============================] - 39s 70ms/step - loss: 1.0612 - accuracy: 0.6396 - val_loss: 2.3316 - val_accuracy: 0.2639
# Epoch 2/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.5098 - accuracy: 0.8528
# Epoch 2: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 40ms/step - loss: 0.5090 - accuracy: 0.8531 - val_loss: 1.3523 - val_accuracy: 0.3923
# Epoch 3/50
# 178/178 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8967
# Epoch 3: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 36ms/step - loss: 0.3561 - accuracy: 0.8967 - val_loss: 1.3546 - val_accuracy: 0.4257
# Epoch 4/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.2951 - accuracy: 0.9123
# Epoch 4: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 38ms/step - loss: 0.2948 - accuracy: 0.9124 - val_loss: 0.9148 - val_accuracy: 0.5305
# Epoch 5/50
# 178/178 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9268
# Epoch 5: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.2482 - accuracy: 0.9268 - val_loss: 1.1672 - val_accuracy: 0.5091
# Epoch 6/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.2221 - accuracy: 0.9349
# Epoch 6: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.2223 - accuracy: 0.9348 - val_loss: 1.2953 - val_accuracy: 0.4971
# Epoch 7/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1950 - accuracy: 0.9438
# Epoch 7: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 40ms/step - loss: 0.1950 - accuracy: 0.9438 - val_loss: 1.0264 - val_accuracy: 0.5268
# Epoch 8/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9490
# Epoch 8: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.1732 - accuracy: 0.9490 - val_loss: 0.7797 - val_accuracy: 0.6140
# Epoch 9/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9533
# Epoch 9: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 36ms/step - loss: 0.1565 - accuracy: 0.9533 - val_loss: 0.8083 - val_accuracy: 0.6144
# Epoch 10/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9570
# Epoch 10: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 33ms/step - loss: 0.1484 - accuracy: 0.9568 - val_loss: 1.1412 - val_accuracy: 0.5451
# Epoch 11/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1477 - accuracy: 0.9559
# Epoch 11: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 33ms/step - loss: 0.1482 - accuracy: 0.9558 - val_loss: 0.9055 - val_accuracy: 0.5910
# Epoch 12/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9599
# Epoch 12: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 42ms/step - loss: 0.1414 - accuracy: 0.9599 - val_loss: 0.9602 - val_accuracy: 0.5912
# Epoch 13/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1190 - accuracy: 0.9668
# Epoch 13: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 38ms/step - loss: 0.1190 - accuracy: 0.9668 - val_loss: 0.4887 - val_accuracy: 0.7670
# Epoch 14/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9729
# Epoch 14: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 38ms/step - loss: 0.1010 - accuracy: 0.9729 - val_loss: 0.7211 - val_accuracy: 0.7359
# Epoch 15/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1121 - accuracy: 0.9678
# Epoch 15: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 36ms/step - loss: 0.1122 - accuracy: 0.9677 - val_loss: 0.4362 - val_accuracy: 0.8396
# Epoch 16/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9666
# Epoch 16: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 35ms/step - loss: 0.1188 - accuracy: 0.9665 - val_loss: 1.2558 - val_accuracy: 0.5488
# Epoch 17/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.1020 - accuracy: 0.9721
# Epoch 17: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 40ms/step - loss: 0.1021 - accuracy: 0.9721 - val_loss: 0.7270 - val_accuracy: 0.7282
# Epoch 18/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0978 - accuracy: 0.9705
# Epoch 18: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 33ms/step - loss: 0.0977 - accuracy: 0.9706 - val_loss: 0.4873 - val_accuracy: 0.8143
# Epoch 19/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9746
# Epoch 19: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 36ms/step - loss: 0.0953 - accuracy: 0.9746 - val_loss: 0.5773 - val_accuracy: 0.7714
# Epoch 20/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9767
# Epoch 20: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 33ms/step - loss: 0.0849 - accuracy: 0.9767 - val_loss: 0.7952 - val_accuracy: 0.7317
# Epoch 21/50
# 176/178 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9762
# Epoch 21: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0876 - accuracy: 0.9762 - val_loss: 0.6858 - val_accuracy: 0.7375
# Epoch 22/50
# 178/178 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9729
# Epoch 22: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 42ms/step - loss: 0.1005 - accuracy: 0.9729 - val_loss: 0.7198 - val_accuracy: 0.6821
# Epoch 23/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9783
# Epoch 23: val_loss did not improve from 2.33162
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0763 - accuracy: 0.9782 - val_loss: 0.6662 - val_accuracy: 0.7651
# Epoch 24/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9815
# Epoch 24: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 36ms/step - loss: 0.0747 - accuracy: 0.9813 - val_loss: 0.6220 - val_accuracy: 0.7325
# Epoch 25/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9815
# Epoch 25: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0714 - accuracy: 0.9815 - val_loss: 1.3399 - val_accuracy: 0.6392
# Epoch 26/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9799
# Epoch 26: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0772 - accuracy: 0.9798 - val_loss: 0.6247 - val_accuracy: 0.7246
# Epoch 27/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0786 - accuracy: 0.9793
# Epoch 27: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 40ms/step - loss: 0.0786 - accuracy: 0.9793 - val_loss: 0.4908 - val_accuracy: 0.7844
# Epoch 28/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9790
# Epoch 28: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0758 - accuracy: 0.9791 - val_loss: 0.5516 - val_accuracy: 0.7732
# Epoch 29/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9821
# Epoch 29: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0659 - accuracy: 0.9822 - val_loss: 0.7784 - val_accuracy: 0.7016
# Epoch 30/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9815
# Epoch 30: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 39ms/step - loss: 0.0749 - accuracy: 0.9815 - val_loss: 0.6364 - val_accuracy: 0.7649
# Epoch 31/50
# 176/178 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9841
# Epoch 31: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0667 - accuracy: 0.9841 - val_loss: 0.8870 - val_accuracy: 0.7213
# Epoch 32/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0701 - accuracy: 0.9808
# Epoch 32: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 39ms/step - loss: 0.0700 - accuracy: 0.9809 - val_loss: 0.3088 - val_accuracy: 0.8757
# Epoch 33/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9872
# Epoch 33: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 32ms/step - loss: 0.0562 - accuracy: 0.9872 - val_loss: 0.5330 - val_accuracy: 0.8291
# Epoch 34/50
# 176/178 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9824
# Epoch 34: val_loss did not improve from 2.33162
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0693 - accuracy: 0.9825 - val_loss: 0.4349 - val_accuracy: 0.8720
# Epoch 35/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9823
# Epoch 35: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 41ms/step - loss: 0.0667 - accuracy: 0.9823 - val_loss: 0.3586 - val_accuracy: 0.8695
# Epoch 36/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9854
# Epoch 36: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0587 - accuracy: 0.9854 - val_loss: 0.3067 - val_accuracy: 0.8635
# Epoch 37/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0588 - accuracy: 0.9843
# Epoch 37: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0588 - accuracy: 0.9844 - val_loss: 0.3698 - val_accuracy: 0.8331
# Epoch 38/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9842
# Epoch 38: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 35ms/step - loss: 0.0556 - accuracy: 0.9843 - val_loss: 1.4187 - val_accuracy: 0.6198
# Epoch 39/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9838
# Epoch 39: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 33ms/step - loss: 0.0640 - accuracy: 0.9839 - val_loss: 0.3783 - val_accuracy: 0.8505
# Epoch 40/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9880
# Epoch 40: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 40ms/step - loss: 0.0517 - accuracy: 0.9879 - val_loss: 0.4736 - val_accuracy: 0.8345
# Epoch 41/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9805
# Epoch 41: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0718 - accuracy: 0.9805 - val_loss: 0.3388 - val_accuracy: 0.8264
# Epoch 42/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0582 - accuracy: 0.9832
# Epoch 42: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0583 - accuracy: 0.9831 - val_loss: 0.6260 - val_accuracy: 0.8017
# Epoch 43/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9869
# Epoch 43: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 41ms/step - loss: 0.0493 - accuracy: 0.9869 - val_loss: 0.3709 - val_accuracy: 0.8018
# Epoch 44/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9871
# Epoch 44: val_loss did not improve from 2.33162
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0502 - accuracy: 0.9871 - val_loss: 0.2666 - val_accuracy: 0.9056
# Epoch 45/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9906
# Epoch 45: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 37ms/step - loss: 0.0451 - accuracy: 0.9906 - val_loss: 0.4696 - val_accuracy: 0.8192
# Epoch 46/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9879
# Epoch 46: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 37ms/step - loss: 0.0478 - accuracy: 0.9879 - val_loss: 0.7518 - val_accuracy: 0.7287
# Epoch 47/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9876
# Epoch 47: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0520 - accuracy: 0.9876 - val_loss: 0.3935 - val_accuracy: 0.8402
# Epoch 48/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9855
# Epoch 48: val_loss did not improve from 2.33162
# 178/178 [==============================] - 7s 42ms/step - loss: 0.0610 - accuracy: 0.9856 - val_loss: 0.4064 - val_accuracy: 0.8646
# Epoch 49/50
# 178/178 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9862
# Epoch 49: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0569 - accuracy: 0.9862 - val_loss: 0.4599 - val_accuracy: 0.8038
# Epoch 50/50
# 177/178 [============================>.] - ETA: 0s - loss: 0.0447 - accuracy: 0.9889
# Epoch 50: val_loss did not improve from 2.33162
# 178/178 [==============================] - 6s 34ms/step - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.2748 - val_accuracy: 0.9235

# %%
import pickle
with open('/content/drive/My Drive/Colab Notebooks/Skin Cancer/history_Res.pickle', 'wb') as file:
    pickle.dump(history.history, file)

# %%
ensemble_model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer =optimizer,
              metrics = ['accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#Assuming you have saved the history during training, load it here

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
ensemble_model.load_weights('/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Res.h5')

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from sklearn.metrics import confusion_matrix, classification_report
import PIL
# Resize images to (32, 32) for ResNet50
x_test_pixels = np.array(x_test).reshape(-1, 28, 28, 3)
x_test_resized = np.array([img_to_array(array_to_img(x, scale=False).resize((32, 32))) for x in x_test_pixels])

# Evaluate the model
loss, acc = ensemble_model.evaluate(x_test_resized, y_test, verbose=2)

# Resize an example image for prediction
image = PIL.Image.open('/content/drive/MyDrive/Skin-Cancer-Classification/1234214.jpg')
image = image.resize((32, 32))
img = np.array(image).reshape(-1, 32, 32, 3)

# Make a prediction
result = ensemble_model.predict(img)
print(result[0])

# Convert the result to a list
result = result.tolist()

# Find the class with the maximum probability
max_prob = max(result[0])
class_ind = result[0].index(max_prob)
print(classes[class_ind])

# Resize the test set for confusion matrix and classification report
x_test_resized = np.array([img_to_array(array_to_img(x, scale=False).resize((32, 32))) for x in x_test_pixels])

# Make predictions on the resized test set
y_pred = np.argmax(ensemble_model.predict(x_test_resized), axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 126/126 - 4s - loss: 1.3481 - accuracy: 0.5829 - 4s/epoch - 35ms/step
# 1/1 [==============================] - 2s 2s/step
# [0.29336414 0.25472134 0.14401402 0.07744552 0.0175036  0.1855936
#  0.02735779]
# ('akiec', 'actinic keratoses and intraepithelial carcinomae')
# 126/126 [==============================] - 4s 15ms/step
# Confusion Matrix:
# [[ 111   25    8    3    1    0    0]
#  [  79   97   10    1    6    1    0]
#  [ 157   92  147   10   49    1    0]
#  [  31    9    2   12    2    0    0]
#  [ 301  133  186   36 1954   33    0]
#  [  13   13    5    1    9   14    0]
#  [ 150   39  123    1  138    3    0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.13      0.75      0.22       148
#            1       0.24      0.50      0.32       194
#            2       0.31      0.32      0.31       456
#            3       0.19      0.21      0.20        56
#            4       0.91      0.74      0.81      2643
#            5       0.27      0.25      0.26        55
#            6       0.00      0.00      0.00       454
#
#     accuracy                           0.58      4006
#    macro avg       0.29      0.40      0.31      4006
# weighted avg       0.65      0.58      0.60      4006
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Average, Flatten, Dropout, Dense, BatchNormalization, Conv2D, MaxPool2D
import PIL
import seaborn as sns
import matplotlib.pyplot as plt

# Define paths
train_path = '/content/drive/MyDrive/DL/train_data.csv'
valid_path = '/content/drive/MyDrive/DL/valid_data.csv'
test_path = '/content/drive/MyDrive/DL/test_data.csv'

# Load the dataset
train_set = pd.read_csv(train_path)
valid_set = pd.read_csv(valid_path)
test_set = pd.read_csv(test_path)

# Define classes
classes = {
    0: ('akiec', 'actinic keratoses and intraepithelial carcinomae'),
    1: ('bcc', 'basal cell carcinoma'),
    2: ('bkl', 'benign keratosis-like lesions'),
    3: ('df', 'dermatofibroma'),
    4: ('nv', 'melanocytic nevi'),
    5: ('vasc', 'pyogenic granulomas and hemorrhage'),
    6: ('mel', 'melanoma'),
}

# Extract labels and features from train, validation, and test sets
y_train = train_set['label']
x_train = train_set.drop(columns=['label'])

y_valid = valid_set['label']
x_valid = valid_set.drop(columns=['label'])

y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

columns = list(x_train)

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# Map numeric labels to class names
class_names = [classes[i][0] for i in range(len(classes))]
y_train_names = y_train.map({i: class_names[i] for i in range(len(class_names))})

# Set the style for better visibility
sns.set(style="darkgrid")

from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x_train, y_train = smote.fit_resample(x_train, y_train)

# Display count plot before oversampling
plt.figure(figsize=(10, 6))
ax = sns.countplot(y=y_train_names)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.title('Count Plot Before Oversampling')
plt.show()



# Map numeric labels to class names after oversampling
y_train_names = y_train.map({i: class_names[i] for i in range(len(class_names))})

# Display count plot after oversampling
plt.figure(figsize=(10, 6))
ax = sns.countplot(y=y_train_names)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.title('Count Plot After Oversampling')
plt.show()

# Display random images from the training data
num = np.random.randint(0, len(x_train))
x_train = np.array(x_train, dtype=np.uint8).reshape(-1, 28, 28, 3)
plt.imshow(x_train[num].reshape(28, 28, 3))
plt.title("Random image from training data")
plt.show()

# Load the ResNet50 model
input_resnet50 = Input(shape=(32, 32, 3))
base_model_resnet50 = ResNet50(weights='imagenet', include_top=False, input_tensor=input_resnet50)
for layer in base_model_resnet50.layers:
    layer.trainable = False
output_resnet50 = Sequential([
    base_model_resnet50,
    Flatten(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(7, activation='softmax')
])(input_resnet50)
model_resnet50 = Model(inputs=input_resnet50, outputs=output_resnet50)

# Custom CNN model
model_custom_cnn = Sequential([
    Conv2D(16, kernel_size=(3, 3), input_shape=(32, 32, 3), activation='relu', padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    Conv2D(256, kernel_size=(3, 3), activation='relu'),
    Flatten(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(7, activation='softmax')
])

# Combine the models using model averaging
input_combined = Input(shape=(32, 32, 3))
output_resnet50 = model_resnet50(input_combined)
output_custom_cnn = model_custom_cnn(input_combined)
ensemble_output = Average()([output_resnet50, output_custom_cnn])

# Build the ensemble model
ensemble_model = Model(inputs=input_combined, outputs=ensemble_output)

# Display the ensemble model summary
ensemble_model.summary()

# Model Checkpoint callback
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5',
    mode='max',
    verbose=1,
    save_best_only=True
)

# Model compilation
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
ensemble_model.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Resize images to (32, 32) for training and validation sets
x_train_resized = tf.image.resize(x_train, (32, 32))
x_valid_resized = tf.image.resize(np.array(x_valid, dtype=np.uint8).reshape(-1, 28, 28, 3), (32, 32))

# Model training
history = ensemble_model.fit(x_train_resized,
                             y_train,
                             validation_data=(x_valid_resized, y_valid),
                             batch_size=128,
                             epochs=50,
                             shuffle=True,
                             callbacks=[callback])

# Plot training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Load the best model weights
ensemble_model.load_weights('/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5')

# Evaluate the model on the test set
x_test_pixels = np.array(x_test).reshape(-1, 28, 28, 3)
x_test_resized = np.array([img_to_array(array_to_img(x, scale=False).resize((32, 32))) for x in x_test_pixels])

loss, acc = ensemble_model.evaluate(x_test_resized, y_test, verbose=2)
print(f'Test Loss: {loss}, Test Accuracy: {acc}')



# Resize the test set for confusion matrix and classification report
x_test_resized = np.array([img_to_array(array_to_img(x, scale=False).resize((32, 32))) for x in x_test_pixels])

# Make predictions on the resized test set
y_pred = np.argmax(ensemble_model.predict(x_test_resized), axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# cuda:0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  model (Functional)          (None, 7)                    2415763   ['input_2[0][0]']
#                                                           9
#
#  sequential_1 (Sequential)   (None, 7)                    700711    ['input_2[0][0]']
#
#  average (Average)           (None, 7)                    0         ['model[0][0]',
#                                                                      'sequential_1[0][0]']
#
# ==================================================================================================
# Total params: 24858350 (94.83 MB)
# Trainable params: 1268558 (4.84 MB)
# Non-trainable params: 23589792 (89.99 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 294/294 [==============================] - ETA: 0s - loss: 1.0352 - accuracy: 0.6360
# Epoch 1: val_loss improved from -inf to 1.07805, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 294/294 [==============================] - 39s 43ms/step - loss: 1.0352 - accuracy: 0.6360 - val_loss: 1.0781 - val_accuracy: 0.5754
# Epoch 2/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.6065 - accuracy: 0.7963
# Epoch 2: val_loss did not improve from 1.07805
# 294/294 [==============================] - 10s 33ms/step - loss: 0.6062 - accuracy: 0.7964 - val_loss: 1.0745 - val_accuracy: 0.5964
# Epoch 3/50
# 294/294 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8571
# Epoch 3: val_loss did not improve from 1.07805
# 294/294 [==============================] - 9s 30ms/step - loss: 0.4514 - accuracy: 0.8571 - val_loss: 0.9374 - val_accuracy: 0.6354
# Epoch 4/50
# 294/294 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8872
# Epoch 4: val_loss did not improve from 1.07805
# 294/294 [==============================] - 7s 25ms/step - loss: 0.3753 - accuracy: 0.8872 - val_loss: 1.0101 - val_accuracy: 0.6543
# Epoch 5/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.3277 - accuracy: 0.9054
# Epoch 5: val_loss improved from 1.07805 to 1.11680, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 34ms/step - loss: 0.3278 - accuracy: 0.9053 - val_loss: 1.1168 - val_accuracy: 0.6194
# Epoch 6/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.2912 - accuracy: 0.9172
# Epoch 6: val_loss did not improve from 1.11680
# 294/294 [==============================] - 7s 25ms/step - loss: 0.2915 - accuracy: 0.9172 - val_loss: 1.0342 - val_accuracy: 0.6474
# Epoch 7/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.2690 - accuracy: 0.9248
# Epoch 7: val_loss did not improve from 1.11680
# 294/294 [==============================] - 9s 31ms/step - loss: 0.2691 - accuracy: 0.9248 - val_loss: 0.9793 - val_accuracy: 0.7113
# Epoch 8/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.2465 - accuracy: 0.9315
# Epoch 8: val_loss did not improve from 1.11680
# 294/294 [==============================] - 7s 25ms/step - loss: 0.2467 - accuracy: 0.9315 - val_loss: 1.0012 - val_accuracy: 0.6833
# Epoch 9/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.2205 - accuracy: 0.9432
# Epoch 9: val_loss improved from 1.11680 to 1.20222, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 35ms/step - loss: 0.2205 - accuracy: 0.9432 - val_loss: 1.2022 - val_accuracy: 0.6503
# Epoch 10/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.2170 - accuracy: 0.9429
# Epoch 10: val_loss did not improve from 1.20222
# 294/294 [==============================] - 8s 27ms/step - loss: 0.2170 - accuracy: 0.9428 - val_loss: 1.0578 - val_accuracy: 0.7113
# Epoch 11/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9476
# Epoch 11: val_loss did not improve from 1.20222
# 294/294 [==============================] - 9s 29ms/step - loss: 0.1982 - accuracy: 0.9477 - val_loss: 1.1452 - val_accuracy: 0.6883
# Epoch 12/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9531
# Epoch 12: val_loss improved from 1.20222 to 1.27196, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 33ms/step - loss: 0.1846 - accuracy: 0.9531 - val_loss: 1.2720 - val_accuracy: 0.6603
# Epoch 13/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1779 - accuracy: 0.9557
# Epoch 13: val_loss did not improve from 1.27196
# 294/294 [==============================] - 8s 27ms/step - loss: 0.1778 - accuracy: 0.9558 - val_loss: 1.2057 - val_accuracy: 0.7133
# Epoch 14/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9604
# Epoch 14: val_loss improved from 1.27196 to 1.29290, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 11s 36ms/step - loss: 0.1662 - accuracy: 0.9604 - val_loss: 1.2929 - val_accuracy: 0.6703
# Epoch 15/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1720 - accuracy: 0.9574
# Epoch 15: val_loss did not improve from 1.29290
# 294/294 [==============================] - 7s 25ms/step - loss: 0.1718 - accuracy: 0.9574 - val_loss: 1.2395 - val_accuracy: 0.6983
# Epoch 16/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1551 - accuracy: 0.9661
# Epoch 16: val_loss did not improve from 1.29290
# 294/294 [==============================] - 9s 31ms/step - loss: 0.1551 - accuracy: 0.9661 - val_loss: 1.2061 - val_accuracy: 0.7083
# Epoch 17/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1554 - accuracy: 0.9643
# Epoch 17: val_loss did not improve from 1.29290
# 294/294 [==============================] - 7s 25ms/step - loss: 0.1554 - accuracy: 0.9643 - val_loss: 1.2615 - val_accuracy: 0.7173
# Epoch 18/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1494 - accuracy: 0.9645
# Epoch 18: val_loss improved from 1.29290 to 1.33309, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 35ms/step - loss: 0.1494 - accuracy: 0.9645 - val_loss: 1.3331 - val_accuracy: 0.7043
# Epoch 19/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9632
# Epoch 19: val_loss did not improve from 1.33309
# 294/294 [==============================] - 8s 27ms/step - loss: 0.1475 - accuracy: 0.9632 - val_loss: 1.3323 - val_accuracy: 0.6853
# Epoch 20/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9680
# Epoch 20: val_loss did not improve from 1.33309
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1384 - accuracy: 0.9679 - val_loss: 1.2710 - val_accuracy: 0.7283
# Epoch 21/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9673
# Epoch 21: val_loss did not improve from 1.33309
# 294/294 [==============================] - 8s 28ms/step - loss: 0.1407 - accuracy: 0.9673 - val_loss: 1.3126 - val_accuracy: 0.6963
# Epoch 22/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9680
# Epoch 22: val_loss did not improve from 1.33309
# 294/294 [==============================] - 8s 28ms/step - loss: 0.1338 - accuracy: 0.9680 - val_loss: 1.2670 - val_accuracy: 0.6993
# Epoch 23/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9717
# Epoch 23: val_loss did not improve from 1.33309
# 294/294 [==============================] - 9s 31ms/step - loss: 0.1244 - accuracy: 0.9717 - val_loss: 1.3324 - val_accuracy: 0.7263
# Epoch 24/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9675
# Epoch 24: val_loss did not improve from 1.33309
# 294/294 [==============================] - 12s 42ms/step - loss: 0.1283 - accuracy: 0.9675 - val_loss: 1.3274 - val_accuracy: 0.6953
# Epoch 25/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9704
# Epoch 25: val_loss improved from 1.33309 to 1.38438, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 11s 36ms/step - loss: 0.1196 - accuracy: 0.9704 - val_loss: 1.3844 - val_accuracy: 0.7023
# Epoch 26/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9719
# Epoch 26: val_loss did not improve from 1.38438
# 294/294 [==============================] - 8s 29ms/step - loss: 0.1197 - accuracy: 0.9719 - val_loss: 1.3310 - val_accuracy: 0.7143
# Epoch 27/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1250 - accuracy: 0.9689
# Epoch 27: val_loss improved from 1.38438 to 1.44333, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 35ms/step - loss: 0.1249 - accuracy: 0.9689 - val_loss: 1.4433 - val_accuracy: 0.6883
# Epoch 28/50
# 294/294 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9709
# Epoch 28: val_loss did not improve from 1.44333
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1205 - accuracy: 0.9709 - val_loss: 1.3273 - val_accuracy: 0.6913
# Epoch 29/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1146 - accuracy: 0.9734
# Epoch 29: val_loss did not improve from 1.44333
# 294/294 [==============================] - 8s 27ms/step - loss: 0.1148 - accuracy: 0.9734 - val_loss: 1.4291 - val_accuracy: 0.7013
# Epoch 30/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1121 - accuracy: 0.9720
# Epoch 30: val_loss did not improve from 1.44333
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1122 - accuracy: 0.9721 - val_loss: 1.3836 - val_accuracy: 0.7083
# Epoch 31/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1104 - accuracy: 0.9732
# Epoch 31: val_loss did not improve from 1.44333
# 294/294 [==============================] - 8s 26ms/step - loss: 0.1104 - accuracy: 0.9732 - val_loss: 1.4010 - val_accuracy: 0.7153
# Epoch 32/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9751
# Epoch 32: val_loss did not improve from 1.44333
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1050 - accuracy: 0.9751 - val_loss: 1.3863 - val_accuracy: 0.7053
# Epoch 33/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9746
# Epoch 33: val_loss did not improve from 1.44333
# 294/294 [==============================] - 8s 26ms/step - loss: 0.1053 - accuracy: 0.9746 - val_loss: 1.4059 - val_accuracy: 0.7263
# Epoch 34/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9747
# Epoch 34: val_loss did not improve from 1.44333
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1004 - accuracy: 0.9748 - val_loss: 1.3985 - val_accuracy: 0.7023
# Epoch 35/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9754
# Epoch 35: val_loss did not improve from 1.44333
# 294/294 [==============================] - 8s 26ms/step - loss: 0.0986 - accuracy: 0.9753 - val_loss: 1.4132 - val_accuracy: 0.7233
# Epoch 36/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9698
# Epoch 36: val_loss did not improve from 1.44333
# 294/294 [==============================] - 9s 30ms/step - loss: 0.1107 - accuracy: 0.9697 - val_loss: 1.3344 - val_accuracy: 0.7103
# Epoch 37/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9730
# Epoch 37: val_loss did not improve from 1.44333
# 294/294 [==============================] - 8s 26ms/step - loss: 0.1061 - accuracy: 0.9730 - val_loss: 1.4272 - val_accuracy: 0.6943
# Epoch 38/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9741
# Epoch 38: val_loss improved from 1.44333 to 1.52715, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 35ms/step - loss: 0.1058 - accuracy: 0.9741 - val_loss: 1.5272 - val_accuracy: 0.6693
# Epoch 39/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9723
# Epoch 39: val_loss did not improve from 1.52715
# 294/294 [==============================] - 8s 28ms/step - loss: 0.0999 - accuracy: 0.9723 - val_loss: 1.4273 - val_accuracy: 0.7263
# Epoch 40/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9756
# Epoch 40: val_loss did not improve from 1.52715
# 294/294 [==============================] - 9s 29ms/step - loss: 0.0949 - accuracy: 0.9756 - val_loss: 1.4812 - val_accuracy: 0.7233
# Epoch 41/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9758
# Epoch 41: val_loss did not improve from 1.52715
# 294/294 [==============================] - 8s 28ms/step - loss: 0.0990 - accuracy: 0.9758 - val_loss: 1.5257 - val_accuracy: 0.7003
# Epoch 42/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9750
# Epoch 42: val_loss did not improve from 1.52715
# 294/294 [==============================] - 8s 28ms/step - loss: 0.0985 - accuracy: 0.9749 - val_loss: 1.3689 - val_accuracy: 0.7123
# Epoch 43/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.0959 - accuracy: 0.9734
# Epoch 43: val_loss improved from 1.52715 to 1.56267, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 34ms/step - loss: 0.0959 - accuracy: 0.9734 - val_loss: 1.5627 - val_accuracy: 0.6833
# Epoch 44/50
# 294/294 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9779
# Epoch 44: val_loss did not improve from 1.56267
# 294/294 [==============================] - 8s 28ms/step - loss: 0.0890 - accuracy: 0.9779 - val_loss: 1.4650 - val_accuracy: 0.7053
# Epoch 45/50
# 294/294 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9777
# Epoch 45: val_loss did not improve from 1.56267
# 294/294 [==============================] - 9s 30ms/step - loss: 0.0883 - accuracy: 0.9777 - val_loss: 1.4290 - val_accuracy: 0.7243
# Epoch 46/50
# 294/294 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9754
# Epoch 46: val_loss did not improve from 1.56267
# 294/294 [==============================] - 8s 26ms/step - loss: 0.0937 - accuracy: 0.9754 - val_loss: 1.4526 - val_accuracy: 0.7053
# Epoch 47/50
# 294/294 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9773
# Epoch 47: val_loss did not improve from 1.56267
# 294/294 [==============================] - 9s 30ms/step - loss: 0.0900 - accuracy: 0.9773 - val_loss: 1.4541 - val_accuracy: 0.6973
# Epoch 48/50
# 292/294 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9780
# Epoch 48: val_loss did not improve from 1.56267
# 294/294 [==============================] - 8s 26ms/step - loss: 0.0857 - accuracy: 0.9781 - val_loss: 1.4987 - val_accuracy: 0.7103
# Epoch 49/50
# 294/294 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9767
# Epoch 49: val_loss improved from 1.56267 to 1.62794, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_ensemb.h5
# 294/294 [==============================] - 10s 35ms/step - loss: 0.0881 - accuracy: 0.9767 - val_loss: 1.6279 - val_accuracy: 0.6993
# Epoch 50/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9698
# Epoch 50: val_loss did not improve from 1.62794
# 294/294 [==============================] - 8s 27ms/step - loss: 0.1092 - accuracy: 0.9698 - val_loss: 1.5174 - val_accuracy: 0.7173
# 32/32 - 1s - loss: 1.3925 - accuracy: 0.7136 - 1s/epoch - 42ms/step
# Test Loss: 1.392457365989685, Test Accuracy: 0.7135728597640991
# 32/32 [==============================] - 2s 16ms/step
# Confusion Matrix:
# [[ 10   5   5   0   9   0   1]
#  [  3  41   3   2   5   0   1]
#  [ 13  13  39   0  43   0   7]
#  [  2   3   2   2   3   0   0]
#  [  5  15  14   1 589  10  30]
#  [  0   1   0   0   3   9   0]
#  [  9   7  15   0  57   0  25]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.24      0.33      0.28        30
#            1       0.48      0.75      0.59        55
#            2       0.50      0.34      0.40       115
#            3       0.40      0.17      0.24        12
#            4       0.83      0.89      0.86       664
#            5       0.47      0.69      0.56        13
#            6       0.39      0.22      0.28       113
#
#     accuracy                           0.71      1002
#    macro avg       0.47      0.48      0.46      1002
# weighted avg       0.70      0.71      0.70      1002
