# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
path='/content/drive/MyDrive/Skin-Cancer-Classification-80-10-10 split/hmnist_28_28_RGB.csv'

# %%
df=pd.read_csv(path)

# %%
df.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 10010        184        166        182        188  ...        208        185
# 10011        121        104        103        132  ...         96         79
# 10012        175        156        160        184  ...        204        181
# 10013        167        127        146        169  ...        185        162
# 10014        181        150        133        178  ...        159         79
#
#        pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 10010        187        208        186        186        206        187
# 10011         76         24         23         21          3          4
# 10012        178        181        159        153        172        151
# 10013        167        184        157        166        185        162
# 10014         82        174        137        125        175        139
#
#        pixel2351  label
# 10010        189      0
# 10011          1      0
# 10012        145      0
# 10013        172      0
# 10014        126      6
#
# [5 rows x 2353 columns]

# %%
fractions = np.array([0.8, 0.1, 0.1])
df = df.sample(frac=1)  # Shuffle the DataFrame

train_set, validation_set, test_set = np.array_split(
    df, (fractions.cumsum() * len(df)).astype(int)[:-1]
)

# %%
print(len(train_set))
# Out:
# 8012

# %%
print(len(test_set))
# Out:
# 1002

# %%
df.label.unique()
# Out:
# array([4, 3, 2, 6, 5, 1, 0])

# %%
classes={0:('akiec', 'actinic keratoses and intraepithelial carcinomae'),
         1:('bcc' , 'basal cell carcinoma'),
         2:('bkl', 'benign keratosis-like lesions'),
         3:('df', 'dermatofibroma'),
         4:('nv', ' melanocytic nevi'),
         5:('vasc', ' pyogenic granulomas and hemorrhage'),
         6:('mel', 'melanoma'),}

# %%
y_train=train_set['label']
x_train=train_set.drop(columns=['label'])
y_test=test_set['label']
x_test=test_set.drop(columns=['label'])

columns=list(x_train)

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Assuming y_train is a Series or a list with labels
sns.set(style="darkgrid")  # Set the style for better visibility

# Create the count plot with annotations
ax = sns.countplot(y=y_train)

# Add annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.show()  # Display the plot

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler()
x_train,y_train  = oversample.fit_resample(x_train,y_train)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Assuming y_train is a Series or a list with labels
sns.set(style="darkgrid")  # Set the style for better visibility

# Create the count plot with annotations
ax = sns.countplot(y=y_train)

# Add annotations on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import random
num=random.randint(0,8000)
x_train=np.array(x_train, dtype=np.uint8).reshape(-1,28,28,3)

plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()
num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

# %%
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
import tensorflow as tf

# %%
# Load the DenseNet-169 model (include_top=False means excluding the fully connected layers)
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(32, 32, 3))


# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create a new Sequential model
model = Sequential()

# Add the pre-trained DenseNet-169 base model
model.add(base_model)

# Flatten the output of the base model
model.add(Flatten())

# Add your own dense layers on top
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax'))

# Display the model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 1, 1, 1664)        12642880
#
#  flatten (Flatten)           (None, 1664)              0
#
#  dropout (Dropout)           (None, 1664)              0
#
#  dense (Dense)               (None, 256)               426240
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_4 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 13114503 (50.03 MB)
# Trainable params: 470663 (1.80 MB)
# Non-trainable params: 12643840 (48.23 MB)
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5',

    mode='max',
    verbose=1,
    save_best_only=True
)

# %%
from sklearn.model_selection import train_test_split

# Assuming x_train and y_train are your features and labels

# First, split the data into training and temporary sets (80% training, 20% temporary)
x_train_temp, x_temp, y_train_temp, y_temp = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42
)

# Then, split the temporary set into validation and test sets (50% each)
x_validation, x_test, y_validation, y_test = train_test_split(
    x_temp, y_temp, test_size=0.5, random_state=42
)

# Resize images to (32, 32)
x_train_resized = tf.image.resize(x_train_temp, (32, 32))

# Now, you have the following splits:
# - x_train_resized, y_train_temp: 80% for training
# - x_validation, y_validation: 10% for validation
# - x_test, y_test: 10% for testing

# Continue with the model compilation and training using x_train_resized and y_train_temp
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

history = model.fit(x_train_resized,
                    y_train_temp,
                    validation_data=(x_validation, y_validation),
                    batch_size=128,
                    epochs=50,
                    shuffle=True,
                    callbacks=[callback])
# Out:
# Epoch 1/50
# 235/235 [==============================] - ETA: 0s - loss: 0.8664 - accuracy: 0.6791
# Epoch 1: val_loss did not improve from 1.82137
# 235/235 [==============================] - 30s 55ms/step - loss: 0.8664 - accuracy: 0.6791 - val_loss: 0.9466 - val_accuracy: 0.7106
# Epoch 2/50
# 235/235 [==============================] - ETA: 0s - loss: 0.7782 - accuracy: 0.7126
# Epoch 2: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 42ms/step - loss: 0.7782 - accuracy: 0.7126 - val_loss: 0.5805 - val_accuracy: 0.7872
# Epoch 3/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.7316 - accuracy: 0.7280
# Epoch 3: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 47ms/step - loss: 0.7313 - accuracy: 0.7281 - val_loss: 0.5137 - val_accuracy: 0.8226
# Epoch 4/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.6876 - accuracy: 0.7443
# Epoch 4: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.6873 - accuracy: 0.7444 - val_loss: 0.3926 - val_accuracy: 0.8911
# Epoch 5/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.6652 - accuracy: 0.7546
# Epoch 5: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 42ms/step - loss: 0.6649 - accuracy: 0.7547 - val_loss: 0.3782 - val_accuracy: 0.8636
# Epoch 6/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.6359 - accuracy: 0.7623
# Epoch 6: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 46ms/step - loss: 0.6360 - accuracy: 0.7622 - val_loss: 0.4542 - val_accuracy: 0.8455
# Epoch 7/50
# 235/235 [==============================] - ETA: 0s - loss: 0.6118 - accuracy: 0.7743
# Epoch 7: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 47ms/step - loss: 0.6118 - accuracy: 0.7743 - val_loss: 0.3491 - val_accuracy: 0.8785
# Epoch 8/50
# 235/235 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.7874
# Epoch 8: val_loss did not improve from 1.82137
# 235/235 [==============================] - 9s 37ms/step - loss: 0.5796 - accuracy: 0.7874 - val_loss: 0.3898 - val_accuracy: 0.8685
# Epoch 9/50
# 234/235 [============================>.] - ETA: 0s - loss: 0
50
# 235/235 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8711
# Epoch 41: val_loss did not improve from 1.82137
# 235/235 [==============================] - 12s 53ms/step - loss: 0.3511 - accuracy: 0.8711 - val_loss: 0.1665 - val_accuracy: 0.9565
# Epoch 42/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8773
# Epoch 42: val_loss did not improve from 1.82137
# 235/235 [==============================] - 9s 39ms/step - loss: 0.3381 - accuracy: 0.8773 - val_loss: 0.1033 - val_accuracy: 0.9822
# Epoch 43/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.8746
# Epoch 43: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 47ms/step - loss: 0.3452 - accuracy: 0.8746 - val_loss: 0.1529 - val_accuracy: 0.9569
# Epoch 44/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8762
# Epoch 44: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.3413 - accuracy: 0.8762 - val_loss: 0.1098 - val_accuracy: 0.9798
# Epoch 45/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.8762
# Epoch 45: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.3406 - accuracy: 0.8762 - val_loss: 0.1745 - val_accuracy: 0.9554
# Epoch 46/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8776
# Epoch 46: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 47ms/step - loss: 0.3364 - accuracy: 0.8776 - val_loss: 0.1270 - val_accuracy: 0.9734
# Epoch 47/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8843
# Epoch 47: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.3305 - accuracy: 0.8843 - val_loss: 0.1544 - val_accuracy: 0.9622
# Epoch 48/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.8801
# Epoch 48: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.3249 - accuracy: 0.8801 - val_loss: 0.1192 - val_accuracy: 0.9702
# Epoch 49/50
# 235/235 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8816
# Epoch 49: val_loss did not improve from 1.82137
# 235/235 [==============================] - 11s 47ms/step - loss: 0.3269 - accuracy: 0.8816 - val_loss: 0.0923 - val_accuracy: 0.9854
# Epoch 50/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.3171 - accuracy: 0.8841
# Epoch 50: val_loss did not improve from 1.82137
# 235/235 [==============================] - 10s 43ms/step - loss: 0.3172 - accuracy: 0.8841 - val_loss: 0.0953 - val_accuracy: 0.9842

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.load_weights('/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5')

# %%
# Resize images to (32, 32)
x_test_resized = tf.image.resize(x_test, (32, 32))

# Evaluate the model on the test set
loss, acc = model.evaluate(x_test_resized, y_test, verbose=2)
print(f'Test Loss: {loss}, Test Accuracy: {acc}')
# Out:
# 118/118 - 5s - loss: 1.2682 - accuracy: 0.5448 - 5s/epoch - 42ms/step
# Test Loss: 1.2681766748428345, Test Accuracy: 0.5448496341705322

# %%
import PIL
image=PIL.Image.open('/content/drive/MyDrive/Skin-Cancer-Classification-80-10-10 split/1234214.jpg')
image=image.resize((32,32))
img=x_test[1]
img=np.array(image).reshape(-1,32,32,3)
result=model.predict(img)
print(result[0])
result=result.tolist()
max_prob=max(result[0])
class_ind=result[0].index(max_prob)
print(classes[class_ind])
# Out:
# 1/1 [==============================] - 5s 5s/step
# [0.2697151  0.45193672 0.17510076 0.01616307 0.03310531 0.02095091
#  0.03302816]
# ('bcc', 'basal cell carcinoma')

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = np.argmax(model.predict(x_test_resized), axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# You can also print a classification report for additional metrics
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 118/118 [==============================] - 5s 20ms/step
# Confusion Matrix:
# [[361 134  14  31   3   2   1]
#  [116 347  11  52   6  11   0]
#  [111 135 201  51  41   6  19]
#  [ 71  53   3 393  11   0   0]
#  [ 54  37  51  60 310  12  20]
#  [ 30  53   3  57  21 344  14]
#  [151  65 113  49  27  11  91]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.66      0.50       546
#            1       0.42      0.64      0.51       543
#            2       0.51      0.36      0.42       564
#            3       0.57      0.74      0.64       531
#            4       0.74      0.57      0.64       544
#            5       0.89      0.66      0.76       522
#            6       0.63      0.18      0.28       507
#
#     accuracy                           0.54      3757
#    macro avg       0.59      0.54      0.54      3757
# weighted avg       0.59      0.54      0.54      3757

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import random

# Load the dataset from the specified paths
train_path = '/content/drive/MyDrive/DL/train_data.csv'
valid_path = '/content/drive/MyDrive/DL/valid_data.csv'
test_path = '/content/drive/MyDrive/DL/test_data.csv'

train_set = pd.read_csv(train_path)
valid_set = pd.read_csv(valid_path)
test_set = pd.read_csv(test_path)

# Define classes
classes = {
    0: ('akiec', 'actinic keratoses and intraepithelial carcinomae'),
    1: ('bcc', 'basal cell carcinoma'),
    2: ('bkl', 'benign keratosis-like lesions'),
    3: ('df', 'dermatofibroma'),
    4: ('nv', 'melanocytic nevi'),
    5: ('vasc', 'pyogenic granulomas and hemorrhage'),
    6: ('mel', 'melanoma'),
}

# Extract labels and features from train, validation, and test sets
y_train = train_set['label']
x_train = train_set.drop(columns=['label'])

y_valid = valid_set['label']
x_valid = valid_set.drop(columns=['label'])

y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

# Countplot for better visibility of class distribution in the training set
sns.set(style="darkgrid")
ax = sns.countplot(y=y_train)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.show()

# Oversample to handle class imbalance
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler()
x_train, y_train = oversample.fit_resample(x_train, y_train)

# Countplot after oversampling
sns.set(style="darkgrid")
ax = sns.countplot(y=y_train)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.show()

# Convert features to NumPy array and reshape
x_train = np.array(x_train, dtype=np.uint8).reshape(-1, 28, 28, 3)

# Display random images from the training data
num = random.randint(0, len(x_train))
plt.imshow(x_train[num].reshape(28, 28, 3))
plt.title("Random image from training data")
plt.show()

# Load the DenseNet-169 model
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create a new Sequential model
model = Sequential()
model.add(base_model)
model.add(Flatten())

# Add own dense layers on top
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax'))

# Display the model summary
model.summary()

# Model Checkpoint callback
callback = ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5',
    mode='max',
    verbose=1,
    save_best_only=True
)

# Resize images to (32, 32) for training and validation sets
x_train_resized = tf.image.resize(x_train, (32, 32))
x_valid_resized = tf.image.resize(np.array(x_valid, dtype=np.uint8).reshape(-1, 28, 28, 3), (32, 32))

# Model compilation
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Model training
history = model.fit(x_train_resized,
                    y_train,
                    validation_data=(x_valid_resized, y_valid),
                    batch_size=128,
                    epochs=50,
                    shuffle=True,
                    callbacks=[callback])

# Plot training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Load the best model weights
model.load_weights('/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 1, 1, 1664)        12642880
#
#  flatten_2 (Flatten)         (None, 1664)              0
#
#  dropout_6 (Dropout)         (None, 1664)              0
#
#  dense_10 (Dense)            (None, 256)               426240
#
#  batch_normalization_8 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_9 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  batch_normalization_10 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  batch_normalization_11 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dense_14 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 13114503 (50.03 MB)
# Trainable params: 470663 (1.80 MB)
# Non-trainable params: 12643840 (48.23 MB)
# _________________________________________________________________
# Epoch 1/50
# 293/294 [============================>.] - ETA: 0s - loss: 1.4667 - accuracy: 0.4469
# Epoch 1: val_loss improved from -inf to 1.14168, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 294/294 [==============================] - 27s 50ms/step - loss: 1.4661 - accuracy: 0.4471 - val_loss: 1.1417 - val_accuracy: 0.5594
# Epoch 2/50
# 293/294 [============================>.] - ETA: 0s - loss: 1.0828 - accuracy: 0.5974
# Epoch 2: val_loss improved from 1.14168 to 1.20383, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5
# 294/294 [==============================] - 11s 36ms/step - loss: 1.0832 - accuracy: 0.5973 - val_loss: 1.2038 - val_accuracy: 0.5415
# Epoch 3/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.9395 - accuracy: 0.6507
# Epoch 3: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 29ms/step - loss: 0.9395 - accuracy: 0.6507 - val_loss: 1.0744 - val_accuracy: 0.5854
# Epoch 4/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.8441 - accuracy: 0.6868
# Epoch 4: val_loss did not improve from 1.20383
# 294/294 [==============================] - 10s 33ms/step - loss: 0.8437 - accuracy: 0.6869 - val_loss: 1.0232 - val_accuracy: 0.5904
# Epoch 5/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.7755 - accuracy: 0.7117
# Epoch 5: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 30ms/step - loss: 0.7760 - accuracy: 0.7116 - val_loss: 1.0841 - val_accuracy: 0.5644
# Epoch 6/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.7239 - accuracy: 0.7283
# Epoch 6: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 31ms/step - loss: 0.7240 - accuracy: 0.7282 - val_loss: 1.1775 - val_accuracy: 0.5574
# Epoch 7/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.6848 - accuracy: 0.7430
# Epoch 7: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 31ms/step - loss: 0.6849 - accuracy: 0.7429 - val_loss: 1.0044 - val_accuracy: 0.6024
# Epoch 8/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.6444 - accuracy: 0.7599
# Epoch 8: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 29ms/step - loss: 0.6444 - accuracy: 0.7599 - val_loss: 1.1401 - val_accuracy: 0.5644
# Epoch 9/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.6151 - accuracy: 0.7706
# Epoch 9: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 32ms/step - loss: 0.6152 - accuracy: 0.7704 - val_loss: 1.0349 - val_accuracy: 0.6114
# Epoch 10/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.5888 - accuracy: 0.7799
# Epoch 10: val_loss did not improve from 1.20383
# 294/294 [==============================] - 8s 28ms/step - loss: 0.5889 - accuracy: 0.7798 - val_loss: 1.0716 - val_accuracy: 0.5854
# Epoch 11/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.5675 - accuracy: 0.7920
# Epoch 11: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 32ms/step - loss: 0.5675 - accuracy: 0.7920 - val_loss: 1.0711 - val_accuracy: 0.6104
# Epoch 12/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7979
# Epoch 12: val_loss did not improve from 1.20383
# 294/294 [==============================] - 9s 29ms/step - loss: 0.5442 - accuracy: 0.7979 - val_loss: 1.1141 - val_accuracy: 0.5784
# Epoch 13/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.
saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense.h5
# 294/294 [==============================] - 11s 38ms/step - loss: 0.3046 - accuracy: 0.8886 - val_loss: 1.2113 - val_accuracy: 0.6154
# Epoch 49/50
# 294/294 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.8883
# Epoch 49: val_loss did not improve from 1.21127
# 294/294 [==============================] - 9s 32ms/step - loss: 0.3094 - accuracy: 0.8883 - val_loss: 1.1613 - val_accuracy: 0.6484
# Epoch 50/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.2944 - accuracy: 0.8941
# Epoch 50: val_loss did not improve from 1.21127
# 294/294 [==============================] - 9s 30ms/step - loss: 0.2944 - accuracy: 0.8941 - val_loss: 1.1082 - val_accuracy: 0.6663
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-fba49a8d7ef3> in <cell line: 151>()
#     149
#     150 # Resize images to (32, 32) for the test set
# --> 151 x_test_resized = tf.image.resize(x_test, (32, 32))
#     152
#     153 # Evaluate the model on the test set
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/image_ops_impl.py in _resize_images_common(images, resizer_fn, size, preserve_aspect_ratio, name, skip_resize_if_same)
#    1458       images = array_ops.expand_dims(images, 0)
#    1459     elif images.get_shape().ndims != 4:
# -> 1460       raise ValueError('\'images\' must have either 3 or 4 dimensions.')
#    1461
#    1462     _, height, width, _ = images.get_shape().as_list()
#
# ValueError: 'images' must have either 3 or 4 dimensions.

# %%
# Extract labels and features from the test set
y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

# Convert features to NumPy array and reshape for the test set
x_test = np.array(x_test, dtype=np.uint8).reshape(-1, 28, 28, 3)

# Resize images to (32, 32) for the test set
x_test_resized = tf.image.resize(x_test, (32, 32))

# Evaluate the model on the test set
loss, acc = model.evaluate(x_test_resized, y_test, verbose=2)
print(f'Test Loss: {loss}, Test Accuracy: {acc}')

# Generate confusion matrix
y_pred = np.argmax(model.predict(x_test_resized), axis=1)
conf_matrix = confusion_matrix(y_test, y_pred)

# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 32/32 - 3s - loss: 1.0245 - accuracy: 0.6537 - 3s/epoch - 102ms/step
# Test Loss: 1.0245345830917358, Test Accuracy: 0.6536926031112671
# 32/32 [==============================] - 4s 26ms/step
# Confusion Matrix:
# [[ 16   7   1   0   1   0   5]
#  [  9  24  13   0   4   1   4]
#  [  9   7  63   0   5   0  31]
#  [  0   2   5   4   1   0   0]
#  [  3  10  57   5 459   3 127]
#  [  0   0   3   0   1   9   0]
#  [  4   3  12   2  11   1  80]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.39      0.53      0.45        30
#            1       0.45      0.44      0.44        55
#            2       0.41      0.55      0.47       115
#            3       0.36      0.33      0.35        12
#            4       0.95      0.69      0.80       664
#            5       0.64      0.69      0.67        13
#            6       0.32      0.71      0.44       113
#
#     accuracy                           0.65      1002
#    macro avg       0.50      0.56      0.52      1002
# weighted avg       0.76      0.65      0.69      1002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE  # Import SMOTE

# Load the dataset from the specified paths
train_path = '/content/drive/MyDrive/DL/train_data.csv'
valid_path = '/content/drive/MyDrive/DL/valid_data.csv'
test_path = '/content/drive/MyDrive/DL/test_data.csv'

train_set = pd.read_csv(train_path)
valid_set = pd.read_csv(valid_path)
test_set = pd.read_csv(test_path)

# Define classes
classes = {
    0: ('akiec', 'actinic keratoses and intraepithelial carcinomae'),
    1: ('bcc', 'basal cell carcinoma'),
    2: ('bkl', 'benign keratosis-like lesions'),
    3: ('df', 'dermatofibroma'),
    4: ('nv', 'melanocytic nevi'),
    5: ('vasc', 'pyogenic granulomas and hemorrhage'),
    6: ('mel', 'melanoma'),
}

# Extract labels and features from train, validation, and test sets
y_train = train_set['label']
x_train = train_set.drop(columns=['label'])

y_valid = valid_set['label']
x_valid = valid_set.drop(columns=['label'])

y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

# Countplot for better visibility of class distribution in the training set
sns.set(style="darkgrid")
ax = sns.countplot(y=y_train)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.show()

# Replace the oversampling part with SMOTE
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x_train, y_train = smote.fit_resample(x_train, y_train)

# Countplot after oversampling
sns.set(style="darkgrid")
ax = sns.countplot(y=y_train)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.show()

# Convert features to NumPy array and reshape
x_train = np.array(x_train, dtype=np.uint8).reshape(-1, 28, 28, 3)

# Display random images from the training data
num = np.random.randint(0, len(x_train))
plt.imshow(x_train[num].reshape(28, 28, 3))
plt.title("Random image from training data")
plt.show()

# Load the DenseNet-169 model
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create a new Sequential model
model = Sequential()
model.add(base_model)
model.add(Flatten())

# Add own dense layers on top
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax'))

# Display the model summary
model.summary()

# Model Checkpoint callback
callback = ModelCheckpoint(
    filepath='/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense_smote.h5',
    mode='max',
    verbose=1,
    save_best_only=True
)

# Resize images to (32, 32) for training and validation sets
x_train_resized = tf.image.resize(x_train, (32, 32))
x_valid_resized = tf.image.resize(np.array(x_valid, dtype=np.uint8).reshape(-1, 28, 28, 3), (32, 32))

# Model compilation
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Model training
history = model.fit(x_train_resized,
                    y_train,
                    validation_data=(x_valid_resized, y_valid),
                    batch_size=128,
                    epochs=50,
                    shuffle=True,
                    callbacks=[callback])

# Plot training history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Load the best model weights
model.load_weights('/content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense_smote.h5')

# Extract labels and features from the test set
y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

# Convert features to NumPy array and reshape for the test set
x_test = np.array(x_test, dtype=np.uint8).reshape(-1, 28, 28, 3)

# Resize images to (32, 32) for the test set
x_test_resized = tf.image.resize(x_test, (32, 32))

# Evaluate the model on the test set
loss, acc = model.evaluate(x_test_resized, y_test, verbose=2)
print(f'Test Loss: {loss}, Test Accuracy: {acc}')

# Generate confusion matrix
y_pred = np.argmax(model.predict(x_test_resized), axis=1)
conf_matrix = confusion_matrix(y_test, y_pred)

# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 1, 1, 1664)        12642880
#
#  flatten (Flatten)           (None, 1664)              0
#
#  dropout (Dropout)           (None, 1664)              0
#
#  dense (Dense)               (None, 256)               426240
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_4 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 13114503 (50.03 MB)
# Trainable params: 470663 (1.80 MB)
# Non-trainable params: 12643840 (48.23 MB)
# _________________________________________________________________
# Epoch 1/50
# 294/294 [==============================] - ETA: 0s - loss: 1.4187 - accuracy: 0.4666
# Epoch 1: val_loss improved from -inf to 1.11337, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense_smote.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 294/294 [==============================] - 41s 64ms/step - loss: 1.4187 - accuracy: 0.4666 - val_loss: 1.1134 - val_accuracy: 0.5435
# Epoch 2/50
# 293/294 [============================>.] - ETA: 0s - loss: 1.0762 - accuracy: 0.5957
# Epoch 2: val_loss did not improve from 1.11337
# 294/294 [==============================] - 11s 37ms/step - loss: 1.0765 - accuracy: 0.5956 - val_loss: 0.9877 - val_accuracy: 0.6054
# Epoch 3/50
# 294/294 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.6359
# Epoch 3: val_loss did not improve from 1.11337
# 294/294 [==============================] - 10s 34ms/step - loss: 0.9714 - accuracy: 0.6359 - val_loss: 1.0608 - val_accuracy: 0.5744
# Epoch 4/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.9035 - accuracy: 0.6638
# Epoch 4: val_loss improved from 1.11337 to 1.15240, saving model to /content/drive/My Drive/Colab Notebooks/Skin Cancer/best_model_Dense_smote.h5
# 294/294 [==============================] - 12s 40ms/step - loss: 0.9034 - accuracy: 0.6638 - val_loss: 1.1524 - val_accuracy: 0.5534
# Epoch 5/50
# 294/294 [==============================] - ETA: 0s - loss: 0.8643 - accuracy: 0.6788
# Epoch 5: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 36ms/step - loss: 0.8643 - accuracy: 0.6788 - val_loss: 1.0536 - val_accuracy: 0.5714
# Epoch 6/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.8117 - accuracy: 0.6995
# Epoch 6: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 37ms/step - loss: 0.8120 - accuracy: 0.6994 - val_loss: 1.0433 - val_accuracy: 0.5764
# Epoch 7/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.7835 - accuracy: 0.7096
# Epoch 7: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 34ms/step - loss: 0.7838 - accuracy: 0.7095 - val_loss: 0.9611 - val_accuracy: 0.6064
# Epoch 8/50
# 294/294 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.7169
# Epoch 8: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 37ms/step - loss: 0.7651 - accuracy: 0.7169 - val_loss: 0.9538 - val_accuracy: 0.6104
# Epoch 9/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.7391 - accuracy: 0.7254
# Epoch 9: val_loss did not improve from 1.15240
# 294/294 [==============================] - 9s 32ms/step - loss: 0.7391 - accuracy: 0.7254 - val_loss: 1.0124 - val_accuracy: 0.5854
# Epoch 10/50
# 294/294 [==============================] - ETA: 0s - loss: 0.7166 - accuracy: 0.7390
# Epoch 10: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s
50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4734 - accuracy: 0.8246
# Epoch 41: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 36ms/step - loss: 0.4736 - accuracy: 0.8245 - val_loss: 1.0422 - val_accuracy: 0.6224
# Epoch 42/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4744 - accuracy: 0.8290
# Epoch 42: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 35ms/step - loss: 0.4743 - accuracy: 0.8289 - val_loss: 1.0818 - val_accuracy: 0.6114
# Epoch 43/50
# 294/294 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8287
# Epoch 43: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 33ms/step - loss: 0.4724 - accuracy: 0.8287 - val_loss: 1.0845 - val_accuracy: 0.6094
# Epoch 44/50
# 294/294 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.8243
# Epoch 44: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 36ms/step - loss: 0.4794 - accuracy: 0.8243 - val_loss: 1.0111 - val_accuracy: 0.6454
# Epoch 45/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4612 - accuracy: 0.8301
# Epoch 45: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 33ms/step - loss: 0.4614 - accuracy: 0.8300 - val_loss: 1.0334 - val_accuracy: 0.6304
# Epoch 46/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.8335
# Epoch 46: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 35ms/step - loss: 0.4584 - accuracy: 0.8334 - val_loss: 1.0995 - val_accuracy: 0.6254
# Epoch 47/50
# 294/294 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.8357
# Epoch 47: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 36ms/step - loss: 0.4543 - accuracy: 0.8357 - val_loss: 1.0425 - val_accuracy: 0.6314
# Epoch 48/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4547 - accuracy: 0.8335
# Epoch 48: val_loss did not improve from 1.15240
# 294/294 [==============================] - 9s 32ms/step - loss: 0.4550 - accuracy: 0.8334 - val_loss: 1.0631 - val_accuracy: 0.6224
# Epoch 49/50
# 293/294 [============================>.] - ETA: 0s - loss: 0.4490 - accuracy: 0.8371
# Epoch 49: val_loss did not improve from 1.15240
# 294/294 [==============================] - 11s 37ms/step - loss: 0.4491 - accuracy: 0.8371 - val_loss: 1.0302 - val_accuracy: 0.6523
# Epoch 50/50
# 294/294 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.8322
# Epoch 50: val_loss did not improve from 1.15240
# 294/294 [==============================] - 10s 33ms/step - loss: 0.4577 - accuracy: 0.8322 - val_loss: 1.0509 - val_accuracy: 0.6204
# 32/32 - 2s - loss: 1.0518 - accuracy: 0.5818 - 2s/epoch - 76ms/step
# Test Loss: 1.0518152713775635, Test Accuracy: 0.5818363428115845
# 32/32 [==============================] - 3s 21ms/step
# Confusion Matrix:
# [[ 12   5   1   4   0   0   8]
#  [ 10  27   9   3   2   2   2]
#  [ 12  12  52   6   4   2  27]
#  [  2   1   4   4   0   1   0]
#  [ 12  16  49  12 395  26 154]
#  [  0   1   0   0   0  12   0]
#  [ 10   5   7   0   4   6  81]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.21      0.40      0.27        30
#            1       0.40      0.49      0.44        55
#            2       0.43      0.45      0.44       115
#            3       0.14      0.33      0.20        12
#            4       0.98      0.59      0.74       664
#            5       0.24      0.92      0.39        13
#            6       0.30      0.72      0.42       113
#
#     accuracy                           0.58      1002
#    macro avg       0.38      0.56      0.41      1002
# weighted avg       0.76      0.58      0.63      1002
